# %%
from agent import graph

state = graph.invoke({"messages": [{"role": "user", "content": "Who won the euro 2024"}], "max_research_loops": 3, "initial_search_query_count": 3})

# %%
state
# Out:
# {'messages': [HumanMessage(content='Who won the euro 2024', additional_kwargs={}, response_metadata={}, id='59407406-6e29-4343-b4f3-244db609ab85'),
#   AIMessage(content="Spain won the UEFA Euro 2024 championship. They defeated England 2-1 in the final, which was held on July 14, 2024, at the Olympiastadion in Berlin, Germany [aljazeera](https://vertexaisearch.cloud.google.com/id/1-0) [Wikipedia](https://vertexaisearch.cloud.google.com/id/1-2).\n\nThis victory secured Spain a record-breaking fourth European Championship title [aljazeera](https://vertexaisearch.cloud.google.com/id/1-0) [Wikipedia](https://vertexaisearch.cloud.google.com/id/1-2). In the final, Spain's Nico Williams scored first, England's Cole Palmer equalized, and Mikel Oyarzabal scored the late winning goal for Spain [Wikipedia](https://vertexaisearch.cloud.google.com/id/1-2). Spain had a perfect tournament, winning all seven of their matches [Wikipedia](https://vertexaisearch.cloud.google.com/id/1-2).", additional_kwargs={}, response_metadata={}, id='264eea30-e74f-4218-a1f8-6b93e9300497')],
#  'search_query': ['Euro 2024 final match winner results',
#   'Euro 2024 final match winner results'],
#  'web_research_result': ["Search results: \n\n\n\n--- SOURCE 1: Spain vs England 2-1: UEFA Euro 2024 final – as it happened ---\nURL: https://www.aljazeera.com/sports/liveblog/2024/7/14/live-spain-vs-england-uefa-euro-2024-final\n\nSUMMARY:\n<summary>\nSpain defeated England 2-1 in the UEFA Euro 2024 final on July 14, 2024, at the Olympiastadion in Berlin, Germany. This victory secured Spain a record fourth European Championship title. Spain fielded an unchanged team, while England gave defender Luke Shaw his first start since February.\n</summary>\n\n<key_excerpts>\nSpain beat England 2-1 in the final of the European Football Championships, Euro 2024., Spain named an unchanged team for the match at the Olympiastadion in Berlin, Germany while England handed defender Luke Shaw his first start since February.\n</key_excerpts>\n\n--------------------------------------------------------------------------------\n\n\n--- SOURCE 2: Match results at the Euro 2024 football championship - Le Monde ---\nURL: https://www.lemonde.fr/en/sport/euro-2024/results/final/\n\nSUMMARY:\n<summary>\nThe webpage appears to be a collection of news article headlines and summaries from Le Monde, dated around December 2025, covering a wide range of international and domestic topics. The main content includes updates on the Russia-Ukraine war, with Putin signaling readiness for a long conflict and Russian forces targeting Ukrainian railways. It also covers US politics, noting a record defense budget with limits on Trump's military ambitions and analysis of his ideological challenge to Europe. Other stories include a racist scandal in Finland, elections in Bosnia and Herzegovina, farmer protests and a high-profile trial in France, and ongoing conflicts in Gaza and Afghanistan. The latter part of the page is dedicated to the results of the UEFA Euro 2024 football championship, including group stage outcomes and related articles celebrating Spain's victory over England in the final.\n</summary>\n\n<key_excerpts>\nPutin signals readiness for a long war and promises 'new success', In Ukraine, Russian forces increasingly target the railway network, US sets record defense budget but imposes limits on Trump's military ambitions, 'Trump's ideological challenge to Europe is more dangerous than the security one', French anesthetist sentenced to life in prison: 'We cannot bring back our loved ones, but at least there is a semblance of justice'\n</key_excerpts>\n\n--------------------------------------------------------------------------------\n\n\n--- SOURCE 3: UEFA Euro 2024 final - Wikipedia ---\nURL: https://en.wikipedia.org/wiki/UEFA_Euro_2024_final\n\nSUMMARY:\n<summary>\nThe UEFA Euro 2024 final was a football match held on July 14, 2024, at the Olympiastadion in Berlin, Germany. Spain defeated England 2–1 to win a record-breaking fourth UEFA European Championship title. Spain's Nico Williams opened the scoring in the 47th minute, England's Cole Palmer equalized in the 73rd, and Spain's Mikel Oyarzabal scored the winning goal in the 86th minute. The match was attended by notable figures including Prince William, King Felipe VI of Spain, and Prime Ministers Keir Starmer and Pedro Sánchez. Spain won all seven of their matches in the tournament, becoming the first team to do so since France in 1984. England became the first side to lose consecutive European Championship finals.\n</summary>\n\n<key_excerpts>\nSpain won the match 2–1 for their record-breaking fourth UEFA European Championship title, surpassing Germany as the sole record-winners of the competition. Spain won all seven matches they played in the competition, the first side to accomplish this since France won five out of five in 1984. England, meanwhile, became the first side to lose consecutive finals. Nico Williams was named as the man of the match. Spain's Lamine Yamal was named as the UEFA Young Player of the Tournament, making him the youngest ever player to feature in a UEFA Euro or FIFA World Cu ...
#  'sources_gathered': ['https://www.baidu.com',
#   'https://www.google.com',
#   'https://www.bing.com',
#   'https://www.baidu.com',
#   'https://www.google.com',
#   'https://www.bing.com'],
#  'initial_search_query_count': 3,
#  'max_research_loops': 3,
#  'research_loop_count': 1}

# %%
from IPython.display import Markdown

Markdown(state["messages"][-1].content)
# Out:
# Spain won the UEFA Euro 2024 championship. They defeated England 2-1 in the final, which was held on July 14, 2024, at the Olympiastadion in Berlin, Germany [aljazeera](https://vertexaisearch.cloud.google.com/id/1-0) [Wikipedia](https://vertexaisearch.cloud.google.com/id/1-2).
#
# This victory secured Spain a record-breaking fourth European Championship title [aljazeera](https://vertexaisearch.cloud.google.com/id/1-0) [Wikipedia](https://vertexaisearch.cloud.google.com/id/1-2). In the final, Spain's Nico Williams scored first, England's Cole Palmer equalized, and Mikel Oyarzabal scored the late winning goal for Spain [Wikipedia](https://vertexaisearch.cloud.google.com/id/1-2). Spain had a perfect tournament, winning all seven of their matches [Wikipedia](https://vertexaisearch.cloud.google.com/id/1-2).

# %%
state = graph.invoke({"messages": state["messages"] + [{"role": "user", "content": "How has the most titles? List the top 5"}]})

# %%
Markdown(state["messages"][-1].content)
# Out:
# Based on the historical record of the UEFA European Championship (EURO) from 1960 through 2024, the nations with the most titles are as follows:
#
# 1.  **Spain** – 4 titles (most recently in 2024) [UEFA EURO all-time winners 2025](https://www.statista.com/statistics/378217/uefa-euro-titles-winners-and-finalists/?srsltid=AfmBOopI3EAxbkcDFBI05QiM_jbPEhMyKz3GGGuhXAnttkXWuHW7KQuh) [UEFA EURO Winners Ranking! Here's a look at the nations ...](https://www.instagram.com/p/DOSx1ZXkhDb/?hl=en) [Most titles | History | UEFA EURO](https://www.uefa.com/uefaeuro/history/winners/)
# 2.  **Germany** – 3 titles [UEFA EURO all-time winners 2025](https://www.statista.com/statistics/378217/uefa-euro-titles-winners-and-finalists/?srsltid=AfmBOopI3EAxbkcDFBI05QiM_jbPEhMyKz3GGGuhXAnttkXWuHW7KQuh) [UEFA EURO Winners Ranking! Here's a look at the nations ...](https://www.instagram.com/p/DOSx1ZXkhDb/?hl=en) [Most titles | History | UEFA EURO](https://www.uefa.com/uefaeuro/history/winners/)
# 3.  **Italy** – 2 titles [UEFA EURO all-time winners 2025](https://www.statista.com/statistics/378217/uefa-euro-titles-winners-and-finalists/?srsltid=AfmBOopI3EAxbkcDFBI05QiM_jbPEhMyKz3GGGuhXAnttkXWuHW7KQuh) [Most titles | History | UEFA EURO](https://www.uefa.com/uefaeuro/history/winners/)
# 4.  **France** – 2 titles [UEFA EURO all-time winners 2025](https://www.statista.com/statistics/378217/uefa-euro-titles-winners-and-finalists/?srsltid=AfmBOopI3EAxbkcDFBI05QiM_jbPEhMyKz3GGGuhXAnttkXWuHW7KQuh) [UEFA EURO Winners Ranking! Here's a look at the nations ...](https://www.instagram.com/p/DOSx1ZXkhDb/?hl=en) [Most titles | History | UEFA EURO](https://www.uefa.com/uefaeuro/history/winners/)
# 5.  **Netherlands** – 1 title [UEFA EURO all-time winners 2025](https://www.statista.com/statistics/378217/uefa-euro-titles-winners-and-finalists/?srsltid=AfmBOopI3EAxbkcDFBI05QiM_jbPEhMyKz3GGGuhXAnttkXWuHW7KQuh) [Most titles | History | UEFA EURO](https://www.uefa.com/uefaeuro/history/winners/)
#
# **Note:** Several other nations, including Portugal, Denmark, Greece, and the former Soviet Union and Czechoslovakia, have also each won one European Championship title, tying them with the Netherlands for fifth place on the all-time list [UEFA EURO all-time winners 2025](https://www.statista.com/statistics/378217/uefa-euro-titles-winners-and-finalists/?srsltid=AfmBOopI3EAxbkcDFBI05QiM_jbPEhMyKz3GGGuhXAnttkXWuHW7KQuh).
